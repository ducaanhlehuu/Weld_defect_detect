# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Project
# Out:
# /content/drive/MyDrive/Project

# %%
# !cp '/content/drive/MyDrive/Project/yolov5/runs/detect/exp7/air-hole4(hollow-bead)-096.jpg' '/content/drive/MyDrive/Project/steel_weld_tube_new_dataset/Image_test'

# %% [markdown]
# #Setup library

# %%
import os
paths = sorted(os.listdir('/content/drive/MyDrive/Project/steel_weld_tube_new_dataset/train/images'))
len(paths)
# Out:
# 24474

# %%
#%%
# !pip install ultralytics

# %%
# !cd /content/drive/MyDrive/Project && git clone https://github.com/ultralytics/yolov5  # clone

# %%
# !cd /content/drive/MyDrive/Project/yolov5 && pip install -r requirements.txt

# %%
# !unzip /content/drive/MyDrive/Project/steel_weld_tube.zip

# %% [markdown]
# # Sửa file yaml trỏ tới train: /content/drive/MyDrive/Project/steel_weld_tube_new_dataset/train/images

# %%
# !python /content/drive/MyDrive/Project/yolov5/train.py --img 640 --batch 32 --epochs 200 --data /content/drive/MyDrive/Project/steel_weld_tube/data.yaml --weights /content/drive/MyDrive/Project/yolov5/runs/train/exp9/weights/best.pt --cache
# Out:
# train: weights=/content/drive/MyDrive/Project/yolov5/runs/train/exp9/weights/best.pt, cfg=, data=/content/drive/MyDrive/Project/steel_weld_tube/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 5 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
image_path = r'/content/drive/MyDrive/Project/steel_weld_tube/valid/images/air-hole4(hollow-bead)-096.jpg'
# !python /content/drive/MyDrive/Project/yolov5/detect.py --weights /content/drive/MyDrive/Project/yolov5/runs/train/exp12/weights/best.pt --img 640 --source {image_path}
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python /content/drive/MyDrive/Project/yolov5/detect.py --weights /content/drive/MyDrive/Project/yolov5/runs/train/exp12/weights/best.pt --img 640 --source /content/drive/MyDrive/Project/steel_weld_tube/valid/images/air-hole4(hollow-bead)-096.jpg'

# %%
# !python /content/drive/MyDrive/Project/yolov5/detect.py --weights /content/drive/MyDrive/Project/yolov5/runs/train/exp12/weights/best.pt --img 640 --source '/content/drive/MyDrive/Project/steel_weld_tube_new_dataset/Image_test'
# Out:
# detect: weights=['/content/drive/MyDrive/Project/yolov5/runs/train/exp12/weights/best.pt'], source=/content/drive/MyDrive/Project/steel_weld_tube_new_dataset/Image_test, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/Project/steel_weld_tube_new_dataset/Image_test/air-hole10-007.jpg: 448x640 1 Air_hole, 69.8ms
# ...
